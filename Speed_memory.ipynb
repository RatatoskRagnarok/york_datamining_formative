# %%
from memory_profiler import memory_usage, profile
# %load_ext memory_profiler
import pandas as pd
import time

# %%
def load_data():
    df = pd.read_csv('data/Chicage Crime Data.csv', dtype={'Arrest': str, 'Domestic': str})
    return df

# Time the function execution
# %time df = load_data()
# Out:
# CPU times: total: 14.7 s
# Wall time: 41.7 s

# %% [markdown]
# #### Memory usage
#
# For some reason, measuring memory usage in Jupyter gives insane answers, so I did it in a separate script.
#
# Max Memory Used = 2879.0 MiB = 2.81 GB

# %%
len(df)
# Out:
# 7391187

# %%
df.head()
# Out:
#          ID Case Number                    Date                      Block  \
# 0   5741943    HN549294  08/25/2007 09:22:18 AM         074XX N ROGERS AVE
# 1     25953    JE240540  05/24/2021 03:06:00 PM        020XX N LARAMIE AVE
# 2     26038    JE279849  06/26/2021 09:24:00 AM      062XX N MC CORMICK RD
# 3  13279676    JG507211  11/09/2023 07:30:00 AM           019XX W BYRON ST
# 4  13274752    JG501049  11/12/2023 07:59:00 AM  086XX S COTTAGE GROVE AVE
#
#    IUCR Primary Type                                        Description  \
# 0  0560      ASSAULT                                             SIMPLE
# 1  0110     HOMICIDE                                FIRST DEGREE MURDER
# 2  0110     HOMICIDE                                FIRST DEGREE MURDER
# 3  0620     BURGLARY                                     UNLAWFUL ENTRY
# 4  0454      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description Arrest Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %% [markdown]
# ### R
#
# Time to load dataset: 83.20 s
#
# Max Memory used: 2.07 GB

# %% [markdown]
# ### WEKA
#
# Time to load dataset: 102.448 s
#
# Max memory used: 3753 MB = 3.67 GB

# %%
# Add data to the DataFrame
data = {
    'Measure': ['Time (s)', 'Memory Usage (GB)'],
    'Python': [41.7, 2.81],
    'WEKA': [102.448, 3.67],
    'R': [83.20, 2.07]
}

df = pd.DataFrame(data)

df
# Out:
#              Measure  Python     WEKA      R
# 0           Time (s)   41.70  102.448  83.20
# 1  Memory Usage (GB)    2.81    3.670   2.07

# %%
df.to_csv('data/memory.csv', index=False)
