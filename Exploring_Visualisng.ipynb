# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data/StudentsPerformance.csv')

# %% [markdown]
# # Viewing the data

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### In R
#
# ![image.png](attachment:b36c0583-5477-4a84-ade5-17c2bd1b5894.png)

# %% [markdown]
# ### Comparison with WEKA
#
# This was possible using the Edit function. There may be another way, but this worked.
# ![image.png](attachment:5f24dc88-d5e4-44d8-b920-0184128363a6.png)

# %% [markdown]
# # Getting basic information about the data

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### In R
#
# ![image.png](attachment:c69e9a91-64a9-4e2c-97a8-62186c2f430a.png)

# %% [markdown]
# ### Comparison with WEKA
#
# Some of this information is available individually for each of the attributes.
#
# ![image.png](attachment:fac3b598-56a3-4a9f-94cf-5a53e932693c.png)

# %%
# moving onto the nominal data
cat_cols = ['gender', 'race/ethnicity', 'lunch',
       'test preparation course', 'parental level of education']
for col in cat_cols:
    print(df[col].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ['standard' 'free/reduced']
# ['none' 'completed']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']

# %% [markdown]
# ### In R
#
# ![image.png](attachment:8bc995ef-813c-491d-82d6-f80dc0252017.png)

# %%
df_cat = df[cat_cols]
df_cat.describe(include='all')
# Out:
#         gender race/ethnicity     lunch test preparation course  \
# count     1000           1000      1000                    1000
# unique       2              5         2                       2
# top     female        group C  standard                    none
# freq       518            319       645                     642
#
#        parental level of education
# count                         1000
# unique                           6
# top                   some college
# freq                           226

# %% [markdown]
# ### In R
#
# ![image.png](attachment:acf9853f-5138-4e9d-829b-57a950dcd552.png)

# %% [markdown]
# ### Comparison with WEKA
#
# Some of this information is available individually for each of the attributes.
#
# ![image.png](attachment:5d2ff8b9-043e-43ef-b372-1d119a1fc747.png)

# %% [markdown]
# ### sneak peek at possible correlations

# %%
num_cols = ['math score', 'reading score', 'writing score']
df_num = df[num_cols]
df_num.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# ### In R
#
# ![image.png](attachment:c2e8c64d-7737-4410-82ce-b34c0902f916.png)

# %% [markdown]
# ### Comparison with WEKA
#
# This is sort of possible, for one attribute at a time, using CorrelationAttributeEval. In an improvement on python, it works on the nominal data without needing explict conversion to numbers
#
# ![image.png](attachment:1d760139-7977-4181-8c57-535761cf3a71.png)

# %% [markdown]
# # Visualising Data

# %% [markdown]
# ## Categorical Data Plots
#
# ### Bar chart

# %%
df['gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar Chart of Categories')
plt.show()

# %% [markdown]
# ### In R
#
# ![image.png](attachment:7a05cd89-9301-4a33-b834-335e038587e0.png)

# %% [markdown]
# ### Comparison with WEKA
#
# These are drawn automatically for categorical data.
#
# ![image.png](attachment:dc145e67-773b-4c34-903d-12e0b36b55b3.png)

# %% [markdown]
# ### Pie Chart

# %%
df['parental level of education'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('parental level of education Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### In R
#
# ![image.png](attachment:8e51f21b-ec7c-46f0-8e73-5ba117719576.png)

# %% [markdown]
# ### Comparison with WEKA
#
# This is not possible

# %% [markdown]
# ## Numerical Data Plots
#
# ### Box plot
# Helps show outliers

# %%
sns.boxplot(data=df_num)
plt.show()

# %% [markdown]
# ### In R
#
# ![image.png](attachment:6c0dae3e-5201-4134-a0ad-c7694d50ecc0.png)

# %% [markdown]
# ### Comparison with WEKA
#
# This is not possible.

# %% [markdown]
# ### Pairwise Plot
# includes histograms to show distribution and plots to show possible correlations

# %%
sns.pairplot(df)
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# ### In R
#
# ![image.png](attachment:8ca5b1b8-00a1-481a-ab2a-cd4e0f7676b2.png)

# %% [markdown]
# ### Comparison with WEKA
#
# Automatically drawn when data imported.
#
# ![image.png](attachment:88a697e4-56c2-40ba-8247-a2de2160e89f.png)

# %% [markdown]
# ### heat map
# shows multiple correlations

# %%
sns.heatmap(df_num.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### In R
#
# ![image.png](attachment:f0f27ca9-371a-4f1a-99d6-784e4d51a89a.png)

# %% [markdown]
# ### Comparison with WEKA
#
# This is not possible.
